# %% [markdown]
# Import Necessary Libraries

# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt

# %% [markdown]
# Check api response

# %%
response_API = requests.get('https://boardgamegeek.com/xmlapi/boardgame/251696')
print(response_API.status_code)
# Out:
# 200

# %%
game_info_35424 = response_API.text
print(game_info_35424)
# Out:
# <boardgames termsofuse="https://boardgamegeek.com/xmlapi/termsofuse">
# 			<boardgame objectid="251696" subtypemismatch="true">
#    <yearpublished></yearpublished>
#    <minplayers></minplayers>
#    <maxplayers></maxplayers>
#    <playingtime></playingtime>
#    <minplaytime></minplaytime>
#    <maxplaytime></maxplaytime>
#    <age></age>
#
#    	   <name primary="true" sortindex="1">Emily Wants to Play Too</name>
#
#    <description>User Summary&lt;br/&gt;&lt;br/&gt;Emily Wants to Play Too is a sequel to the original game, Emily Wants to Play.&lt;br/&gt;&lt;br/&gt;It was developed by Shawn Hitchcock.&lt;br/&gt;&lt;br/&gt;</description>
#
#    	   <thumbnail>https://cf.geekdo-images.com/KL_CYsOwBtxNnSDsNZfTnA__thumb/img/9PRooKUNgQYobbHIwrJG770Rv7E=/fit-in/200x150/filters:strip_icc()/pic4101386.jpg</thumbnail>
# 	   https://cf.geekdo-images.com/KL_CYsOwBtxNnSDsNZfTnA__original/img/PRA1CY8uxL6eZWyZzksfTd7D6tg=/0x0/filters:format(jpeg)/pic4101386.jpg
#
# ...

# %%
df_board_game_rankings = pd.read_csv('.\\.venv\\data\\boardgames_ranks.csv')
df_board_game_rankings.head()
# Out:
#        id                               name  yearpublished  rank  \
# 0  224517                  Brass: Birmingham           2018     1
# 1  161936          Pandemic Legacy: Season 1           2015     2
# 2  174430                         Gloomhaven           2017     3
# 3  342942                           Ark Nova           2021     4
# 4  233078  Twilight Imperium: Fourth Edition           2017     5
#
#    bayesaverage  average  usersrated  is_expansion  abstracts_rank  cgs_rank  \
# 0       8.41277  8.59213       48001             0             NaN       NaN
# 1       8.37571  8.52498       54148             0             NaN       NaN
# 2       8.34398  8.57972       63128             0             NaN       NaN
# 3       8.33959  8.53505       46382             0             NaN       NaN
# 4       8.23662  8.59240       24556             0             NaN       NaN
#
#    childrensgames_rank  familygames_rank  partygames_rank  strategygames_rank  \
# ...

# %%
nozerorank = df_board_game_rankings[(df_board_game_rankings['rank'] == 0)].index
df_bgr_nozerorank = pd.DataFrame(df_board_game_rankings.drop(nozerorank, inplace = True))
df_board_game_rankings.head(20)
# Out:
# Empty DataFrame
# Columns: [id, name, yearpublished, rank, bayesaverage, average, usersrated, is_expansion, abstracts_rank, cgs_rank, childrensgames_rank, familygames_rank, partygames_rank, strategygames_rank, thematic_rank, wargames_rank]
# Index: []

# %%
df_bgr2 = pd.read_csv('.\\.venv\\data\\boardgames_ranks.csv')
df_bgr2.head(20)
# Out:
#         id                                           name  yearpublished  \
# 0   224517                              Brass: Birmingham           2018
# 1   161936                      Pandemic Legacy: Season 1           2015
# 2   174430                                     Gloomhaven           2017
# 3   342942                                       Ark Nova           2021
# 4   233078              Twilight Imperium: Fourth Edition           2017
# 5   316554                                 Dune: Imperium           2020
# 6   167791                              Terraforming Mars           2016
# 7   115746                War of the Ring: Second Edition           2011
# 8   187645                           Star Wars: Rebellion           2016
# 9   291457                   Gloomhaven: Jaws of the Lion           2020
# 10  162886                                  Spirit Island           2017
# 11  220308                                   Gaia Project           2017
# ...

# %%
zerorank = df_bgr2[(df_bgr2['rank'] == 0)].index
df_bgr_nozero = pd.DataFrame(df_bgr2.drop(zerorank, inplace = True))
df_bgr2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27288 entries, 0 to 27287
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   27288 non-null  int64
#  1   name                 27288 non-null  object
#  2   yearpublished        27288 non-null  int64
#  3   rank                 27288 non-null  int64
#  4   bayesaverage         27288 non-null  float64
#  5   average              27288 non-null  float64
#  6   usersrated           27288 non-null  int64
#  7   is_expansion         27288 non-null  int64
#  8   abstracts_rank       1424 non-null   float64
#  9   cgs_rank             362 non-null    float64
#  10  childrensgames_rank  1073 non-null   float64
#  11  familygames_rank     3314 non-null   float64
#  12  partygames_rank      912 non-null    float64
#  13  strategygames_rank   2992 non-null   float64
#  14  thematic_rank        1671 non-null   float64
# ...

# %%
df_bgr_nozero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame
